# %%
from yolo import YOLO
import cv2
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
y = YOLO(model_path="/data/tmp/logs_ff/002/trained_weights_stage_1.h5",
        anchors_path="model_data/resized_food_facts_anchors.txt",
        classes_path="model_data/food_facts_classes.txt",
        score=0.1,
        iou=0.2,
        model_image_size=(416,416))
# Out:
# /data/tmp/logs_ff/002/trained_weights_stage_1.h5 model, anchors, and classes loaded.

# %%
y.detect_image(image=Image.open("test_images/d68cad54-a664-4a20-a73e-77e138a2af77_1.d0d2b0fbf6845f061aa44e900a543a1e.jpeg"))
# Out:
# (416, 416, 3)
# Found 0 boxes for img
# 2.812346399005037
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375 at 0x7F657899C160>

# %%
y.detect_image(image=Image.open("/data/tmp/logs_ff/001/14d00c9d-75a5-4134-91bc-78d4eb12a071_1.fc6feb0f5a5151e8026fa92e9c1b44e1.jpeg"))
# Out:
# (416, 416, 3)
# Found 0 boxes for img
# 0.043729658995289356
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=608x552 at 0x7F610EE94320>

# %%
y.detect_image(image=Image.open("/data/tmp/toothpastes/US_toothpastes/P9918016_Total_Clean_Mint_Paste_1p9oz_Ctn_US.jpeg"))
# Out:
# (416, 416, 3)
# Found 0 boxes for img
# 0.6675569150247611
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk)
#     726     try:
# --> 727         rawmode, mode = _OUTMODES[mode]
#     728     except KeyError:
#
# KeyError: 'CMYK'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.5/dist-packages/PIL/Image.py in _repr_png_(self)
# ...

# %%
f = y.detect_image(image=Image.open('/data/tmp/nutrition_label_dataset_abon/post_consumer_brands/malt_o_meal/00042400214434_PF_PDF__.jpg'))
# Out:
# (416, 416, 3)
# Found 0 boxes for img
# 0.16523372998926789

# %%
y.detect_image(image=Image.open('/data/tmp/trash/00042400214434_PF_PDF__.jpg'))
# Out:
# (416, 416, 3)
# Found 0 boxes for img
# 0.03951578796841204
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x321 at 0x7F610EE62550>

# %%
from matplotlib.pyplot import imshow
import numpy as np
type(f)
imshow(np.asarray(f))
#f.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk)
#     726     try:
# --> 727         rawmode, mode = _OUTMODES[mode]
#     728     except KeyError:
#
# KeyError: 'CMYK'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.5/dist-packages/PIL/Image.py in _repr_png_(self)
#     670         from io import BytesIO
#     671         b = BytesIO()
# ...

# %%
y.detect_image(image=Image.open("/data/tmp/toothpastes/US_toothpastes/P9919886_Enamel_Health_TP_Sensitive_5p5oz_Carton_US.jpeg"))
# Out:
# (416, 416, 3)
# Found 0 boxes for img
# 0.7495792449917644
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk)
#     726     try:
# --> 727         rawmode, mode = _OUTMODES[mode]
#     728     except KeyError:
#
# KeyError: 'CMYK'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.5/dist-packages/PIL/Image.py in _repr_png_(self)
# ...

# %%
y_orig = YOLO()
# Out:
# model_data/yolo.h5 model, anchors, and classes loaded.

# %%
y_orig.detect_image(image=Image.open("test_images/d68cad54-a664-4a20-a73e-77e138a2af77_1.d0d2b0fbf6845f061aa44e900a543a1e.jpeg"))
# Out:
# (416, 416, 3)
# Found 2 boxes for img
# traffic light 0.33 (198, 115) (277, 159)
# aeroplane 0.39 (29, 91) (482, 296)
# 4.189452115999302
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375 at 0x7F25D7810780>

# %%
y_orig.detect_image(image=Image.open("/data/tmp/toothpastes/US_toothpastes/P9918016_Total_Clean_Mint_Paste_1p9oz_Ctn_US.jpeg"))
# Out:
# (416, 416, 3)
# Found 1 boxes for img
# tvmonitor 0.39 (326, 0) (4876, 3300)
# 0.6693164699827321
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk)
#     726     try:
# --> 727         rawmode, mode = _OUTMODES[mode]
#     728     except KeyError:
#
# KeyError: 'CMYK'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ...

# %%
t = Image.open("/data/tmp/toothpastes/US_toothpastes/P9918016_Total_Clean_Mint_Paste_1p9oz_Ctn_US.jpeg")

# %%
cv2.imread("/data/tmp/toothpastes/US_toothpastes/P9918016_Total_Clean_Mint_Paste_1p9oz_Ctn_US.jpeg")
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...
