# %%
import glob
import re
import os
import cv2

BOUNDING_BOX_PADDING = 5

# %% [markdown]
# f_p = open("data/train_nutrition_facts_postive.txt", "w")
# f_n = open("data/train_nutrition_facts_negative.txt", "w")
#
# jpg_files = glob.glob("/data/tmp/nutrition_label_dataset_abon/post_consumer_brands/*/*.jpg")
# jpg_files

# %%
f_p = open("data/resized_train_nutrition_facts_postive.txt", "w")
f_n = open("data/resized_train_nutrition_facts_negative.txt", "w")

jpg_files = glob.glob("/data/tmp/nutrition_label_dataset_abon_resized/post_consumer_brands/*/*.jpg")
jpg_files
# Out:
# ['/data/tmp/nutrition_label_dataset_abon_resized/post_consumer_brands/cocoa_pebbles/00884912002464_PF_PDF__.jpg',
#  '/data/tmp/nutrition_label_dataset_abon_resized/post_consumer_brands/cocoa_pebbles/00884912129659_PF_PDF__.jpg',
#  '/data/tmp/nutrition_label_dataset_abon_resized/post_consumer_brands/cocoa_pebbles/00884912129512_PF_PDF__.jpg',
#  '/data/tmp/nutrition_label_dataset_abon_resized/post_consumer_brands/post/00884912068859_PF_PDF__.jpg',
#  '/data/tmp/nutrition_label_dataset_abon_resized/post_consumer_brands/honey_bunches_of_oats/00884912003416_PF_.jpg',
#  '/data/tmp/nutrition_label_dataset_abon_resized/post_consumer_brands/great_grains/00884912116505_PF_PDF__.jpg',
#  '/data/tmp/nutrition_label_dataset_abon_resized/post_consumer_brands/great_grains/00884912320476_PF_PDF__.jpg',
#  '/data/tmp/nutrition_label_dataset_abon_resized/post_consumer_brands/great_grains/00884912320490_PF_PDF__.jpg',
# ...

# %%
for jpeg in jpg_files:
    txt = re.sub(".jpg",".txt", jpeg)
    if os.path.exists(txt):
        image = cv2.imread(jpeg)
        img_w = image.shape[1]
        img_h = image.shape[0]
        print(jpeg, img_w, img_h)
        ann_txt = open(txt)
        l_w = [jpeg]
        for t in ann_txt:
            t = t.rstrip()
            idx, xcen_n, ycen_n, w_n, h_n = t.split(" ")
            print(idx, xcen_n, ycen_n, w_n, h_n)
            x_cen =  img_w * float(xcen_n)
            y_cen = img_h * float(ycen_n)
            w = img_w * float(w_n)
            h = img_h * float(h_n)
            xmin = int(x_cen - (w/2) - BOUNDING_BOX_PADDING)
            ymin = int(y_cen - (h/2) - BOUNDING_BOX_PADDING)
            xmax = int(x_cen + (w/2) + BOUNDING_BOX_PADDING)
            ymax = int(y_cen + (h/2) + BOUNDING_BOX_PADDING)
            l_w.append("{},{},{},{},{}".format(xmin, ymin, xmax, ymax, 2))
        print(" ".join(l_w))
        f_p.write(" ".join(l_w) + "\n")
    else:
        f_n.write("{} 0,0,1,1,0\n".format(jpeg))
# Out:
# /data/tmp/nutrition_label_dataset_abon_resized/post_consumer_brands/cocoa_pebbles/00884912002464_PF_PDF__.jpg 416 366
# 0 0.537500 0.501578 0.072778 0.421086
# /data/tmp/nutrition_label_dataset_abon_resized/post_consumer_brands/cocoa_pebbles/00884912002464_PF_PDF__.jpg 203,101,243,265,2
# /data/tmp/nutrition_label_dataset_abon_resized/post_consumer_brands/cocoa_pebbles/00884912129659_PF_PDF__.jpg 416 352
# 0 0.532929 0.475768 0.075679 0.494198
# /data/tmp/nutrition_label_dataset_abon_resized/post_consumer_brands/cocoa_pebbles/00884912129659_PF_PDF__.jpg 200,75,242,259,2
# /data/tmp/nutrition_label_dataset_abon_resized/post_consumer_brands/cocoa_pebbles/00884912129512_PF_PDF__.jpg 416 336
# 0 0.869378 0.430534 0.075169 0.509924
# /data/tmp/nutrition_label_dataset_abon_resized/post_consumer_brands/cocoa_pebbles/00884912129512_PF_PDF__.jpg 341,53,382,235,2
# /data/tmp/nutrition_label_dataset_abon_resized/post_consumer_brands/post/00884912068859_PF_PDF__.jpg 416 312
# ...

# %%
f_p.close()
f_n.close()
